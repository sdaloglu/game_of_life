# %%
import matplotlib.pyplot as plt
import re

# Function to read the file and extract block size and time
def extract_data(filename):
    data = []
    with open(filename, 'r') as file:
        for line in file:
            # Regular expression to match the pattern "Block size: [number] Time: [number] ms"
            match = re.search(r'Block size: (\d+) Time: ([\d.]+) ms', line)
            if match:
                # Extract block size and time, convert them to appropriate types
                block_size = int(match.group(1))
                time = float(match.group(2))
                data.append((block_size, time))
    return data

# Example usage
filename = 'cache_blocking_time.txt'
extracted_data = extract_data(filename)
print(extracted_data)


# Make a plot from extracted_data
x, y = zip(*extracted_data)
plt.plot(x, y)
plt.xlabel('Block size')
plt.ylabel('Time (ms)')
plt.title('Run time of Game of Life with grid size 1000x1000 over 10 updates as a function of block sizes')
plt.show()
# Out:
# [(1, 96.002), (2, 81.9282), (3, 79.37), (4, 77.6688), (5, 82.8078), (6, 107.897), (7, 166.083), (8, 298.938), (9, 97.3588), (10, 90.3753), (11, 76.1745), (12, 76.0384), (13, 75.6058), (14, 85.0644), (15, 84.1187), (16, 83.157), (17, 77.1955), (18, 82.8727), (19, 82.2891), (20, 81.9953), (21, 82.1189), (22, 80.6682), (23, 79.673), (24, 79.8502), (25, 80.2986), (26, 80.281), (27, 82.87), (28, 81.9714), (29, 80.7212), (30, 79.0915), (31, 78.6808), (32, 78.9567), (33, 79.2135), (34, 78.7308), (35, 88.4516), (36, 86.5067), (37, 80.7503), (38, 100.896), (39, 81.6614), (40, 77.9131), (41, 77.7452), (42, 78.0714), (43, 78.1698), (44, 78.3343), (45, 78.1875), (46, 78.1821), (47, 78.2599), (48, 78.1563), (49, 80.9179), (50, 81.1473), (51, 90.6039), (52, 239.683), (53, 143.653), (54, 93.2172), (55, 89.6069), (56, 90.8982), (57, 108.31), (58, 127.29), (59, 103.214), (60, 98.4236), (61, 110.178), (62, 116.212), (63, 110.704), (64, 126.2)]
